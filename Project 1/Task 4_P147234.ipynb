# %% [markdown]
# # Part 4:Files & Exceptions

# %% [markdown]
# ### Question 1:

# %%
with open('movie.txt') as file_object:
    contents=file_object.read()
    print(contents) 

with open('sport.txt') as file_object:
    contents=file_object.read()
    print(contents)
# Out:
# Avatar
# Avengers
# Titanic
# Joker
# Spiderman
#
#
#
#
# Badminton
# Football
# Cycling
# Hockey
# Volleyball

# %% [markdown]
# ### Question 2:

# %%
filename='movie.txt'
with open(filename,'a') as file_object:
    file_object.write('\nExplanation:')
    file_object.write('\nAvatar-Human colonizers explore and exploit an alien world called Pandora.')
    file_object.write('\nAvengers-A superhero that protect Earth from threats')
    file_object.write('\nTitanic-A poor artist and a rich debunate meet who fall in love on the ill-fated maiden voyage of the unsinkable RMS Titanic in 1912.')
    file_object.write('\nJoker-A man who become a clownish alter ego who commits crimes.')
    file_object.write('\nSpiderman-A teenager that gains superhuman abilities after being bitten by a genetically engineered spider.')

filename='sport.txt'
with open(filename,'a') as file_object:
    file_object.write('\nExplanation:')
    file_object.write('\nBadminton-A  racket sport played using rackets to hit a shuttlecock across a net.')
    file_object.write('\nFootball-A family of team involves kicking a ball to score a goal.')
    file_object.write('\nCycling-Activity of riding a bicycle or other type of cycle.')
    file_object.write('\nHockey-Game between two teams who wear skates and compete on an ice or dry floor.')
    file_object.write('\nVolleyball-Two teams of six players separated by a net, where each score counted by grounding a ball on the other team court.')

# %% [markdown]
# ### Question 3:

# %%
try:
    with open('movie.txt') as file_object:
        contents=file_object.read()
        print(contents) 

    with open('sport.txt') as file_object:
        contents=file_object.read()
        print(contents)

    filename='movie.txt'
    with open(filename,'a') as file_object:
        file_object.write('\nExplanation:')
        file_object.write('\nAvatar-Human colonizers explore and exploit an alien world called Pandora.')
        file_object.write('\nAvengers-A superhero that protect Earth from threats')
        file_object.write('\nTitanic-A poor artist and a rich debunate meet who fall in love on the ill-fated maiden voyage of the unsinkable RMS Titanic in 1912.')
        file_object.write('\nJoker-A man who become a clownish alter ego who commits crimes.')
        file_object.write('\nSpiderman-A teenager that gains superhuman abilities after being bitten by a genetically engineered spider.')

    filename='sport.txt'
    with open(filename,'a') as file_object:
        file_object.write('\nExplanation:')
        file_object.write('\nBadminton-A  racket sport played using rackets to hit a shuttlecock across a net.')
        file_object.write('\nFootball-A family of team involves kicking a ball to score a goal.')
        file_object.write('\nCycling-Activity of riding a bicycle or other type of cycle.')
        file_object.write('\nHockey-Game between two teams who wear skates and compete on an ice or dry floor.')
        file_object.write('\nVolleyball-Two teams of six players separated by a net, where each score counted by grounding a ball on the other team court.')

except FileNotFoundError:
    print()
    msg='Sorry, one of the files is missing.'
    print(msg)
# Out:
# Avatar
# Avengers
# Titanic
# Joker
# Spiderman
#
#
#
#
# Explanation:
# Avatar-Human colonizers explore and exploit an alien world called Pandora.
# Avengers-A superhero that protect Earth from threats
# Titanic-A poor artist and a rich debunate meet who fall in love on the ill-fated maiden voyage of the unsinkable RMS Titanic in 1912.
# Joker-A man who become a clownish alter ego who commits crimes.
# Spiderman-A teenager that gains superhuman abilities after being bitten by a genetically engineered spider.
#
# Sorry, one of the files is missing.
